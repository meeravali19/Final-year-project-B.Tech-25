# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
dataset=pd.read_csv("CSV-03-11/03-11/Portmap.csv")

# %%
dataset.head(5)
# Out:
#    Unnamed: 0                                 Flow ID       Source IP  \
# 0          24          192.168.50.254-224.0.0.5-0-0-0  192.168.50.254
# 1          26          192.168.50.253-224.0.0.5-0-0-0  192.168.50.253
# 2      176563  172.217.10.98-192.168.50.6-443-54799-6    192.168.50.6
# 3       50762    172.217.7.2-192.168.50.6-443-54800-6    192.168.50.6
# 4       87149  172.217.10.98-192.168.50.6-443-54801-6    192.168.50.6
#
#     Source Port  Destination IP   Destination Port   Protocol  \
# 0             0       224.0.0.5                  0          0
# 1             0       224.0.0.5                  0          0
# 2         54799   172.217.10.98                443          6
# 3         54800     172.217.7.2                443          6
# 4         54801   172.217.10.98                443          6
#
#                     Timestamp   Flow Duration   Total Fwd Packets  ...  \
# 0  2018-11-03 09:18:16.964447       114456999                  45  ...
# ...

# %%
dataset.shape
# Out:
# (191694, 88)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191694 entries, 0 to 191693
# Data columns (total 88 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Unnamed: 0                    191694 non-null  int64
#  1   Flow ID                       191694 non-null  object
#  2    Source IP                    191694 non-null  object
#  3    Source Port                  191694 non-null  int64
#  4    Destination IP               191694 non-null  object
#  5    Destination Port             191694 non-null  int64
#  6    Protocol                     191694 non-null  int64
#  7    Timestamp                    191694 non-null  object
#  8    Flow Duration                191694 non-null  int64
#  9    Total Fwd Packets            191694 non-null  int64
#  10   Total Backward Packets       191694 non-null  int64
#  11  Total Length of Fwd Packets   191694 non-null  float64
# ...

# %%
dataset.describe()
# Out:
#           Unnamed: 0    Source Port   Destination Port       Protocol  \
# count  191694.000000  191694.000000      191694.000000  191694.000000
# mean    95846.500000    2088.157068       32152.417843      16.799915
# std     55337.435588    8566.647296       19319.329351       1.485127
# min         0.000000       0.000000           0.000000       0.000000
# 25%     47923.250000     648.000000       15376.500000      17.000000
# 50%     95846.500000     651.000000       32215.000000      17.000000
# 75%    143769.750000     846.000000       48947.000000      17.000000
# max    191693.000000   65528.000000       65535.000000      17.000000
#
#         Flow Duration   Total Fwd Packets   Total Backward Packets  \
# count    1.916940e+05       191694.000000            191694.000000
# mean     3.429798e+05            2.269868                 0.381493
# std      5.957307e+06           46.812214                72.545552
# ...

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'Flow ID', ' Source IP', ' Source Port',
#        ' Destination IP', ' Destination Port', ' Protocol', ' Timestamp',
#        ' Flow Duration', ' Total Fwd Packets', ' Total Backward Packets',
#        'Total Length of Fwd Packets', ' Total Length of Bwd Packets',
#        ' Fwd Packet Length Max', ' Fwd Packet Length Min',
#        ' Fwd Packet Length Mean', ' Fwd Packet Length Std',
#        'Bwd Packet Length Max', ' Bwd Packet Length Min',
#        ' Bwd Packet Length Mean', ' Bwd Packet Length Std', 'Flow Bytes/s',
#        ' Flow Packets/s', ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max',
#        ' Flow IAT Min', 'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std',
#        ' Fwd IAT Max', ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean',
#        ' Bwd IAT Std', ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags',
#        ' Bwd PSH Flags', ' Fwd URG Flags', ' Bwd URG Flags',
#        ' Fwd Header Length', ' Bwd Header Length', 'Fwd Packets/s',
# ...

# %%
dataset[' Label'].value_counts()
# Out:
#  Label
# Portmap    186960
# BENIGN       4734
# Name: count, dtype: int64

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0         0
# Flow ID            0
#  Source IP         0
#  Source Port       0
#  Destination IP    0
#                   ..
#  Idle Max          0
#  Idle Min          0
# SimillarHTTP       0
#  Inbound           0
#  Label             0
# Length: 88, dtype: int64

# %%
unique_counts = dataset.nunique()

# Convert Series to DataFrame
unique_counts_df = unique_counts.reset_index()

# Rename columns for clarity
unique_counts_df.columns = ['Column_Name', 'Unique_Count']

# Display the full DataFrame (optional: remove column width truncation in console)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Show the table
print(unique_counts_df)
# Out:
#                      Column_Name  Unique_Count
# 0                     Unnamed: 0        191694
# 1                        Flow ID        189532
# 2                      Source IP           206
# 3                    Source Port          3243
# 4                 Destination IP           235
# 5               Destination Port         60733
# 6                       Protocol             3
# 7                      Timestamp        191676
# 8                  Flow Duration          3300
# 9              Total Fwd Packets           118
# 10        Total Backward Packets           139
# 11   Total Length of Fwd Packets           662
# 12   Total Length of Bwd Packets           688
# 13         Fwd Packet Length Max           413
# 14         Fwd Packet Length Min            89
# 15        Fwd Packet Length Mean           732
# 16         Fwd Packet Length Std           665
# 17         Bwd Packet Length Max           301
# 18         Bwd Packet Length Min           125
# ...
